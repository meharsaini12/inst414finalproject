# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl.workbook import Workbook
import statistics 
import os

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2010&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2010 = json.loads(response.text)
highlander_df_2010 = pd.json_normalize(highlander_2010)
highlander_df_2010
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        20  sport utility vehicle               22          4           2.7
# 1        18  sport utility vehicle               20          6           3.5
# 2        17  sport utility vehicle               19          6           3.5
# 3        27  sport utility vehicle               26          6           3.3
#
#   drive fuel_type  highway_mpg    make                  model transmission  \
# 0   fwd       gas           27  toyota         highlander 2wd            a
# 1   fwd       gas           24  toyota         highlander 2wd            a
# 2   awd       gas           23  toyota         highlander 4wd            a
# 3   awd       gas           25  toyota  highlander hybrid 4wd            a
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2011&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2011 = json.loads(response.text)
highlander_df_2011 = pd.json_normalize(highlander_2011)
highlander_df_2011
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        20  sport utility vehicle               22          4           2.7
# 1        18  sport utility vehicle               20          6           3.5
# 2        17  sport utility vehicle               19          6           3.5
# 3        28  sport utility vehicle               28          6           3.5
#
#   drive fuel_type  highway_mpg    make                  model transmission  \
# 0   fwd       gas           25  toyota         highlander 2wd            a
# 1   fwd       gas           24  toyota         highlander 2wd            a
# 2   awd       gas           22  toyota         highlander 4wd            a
# 3   awd       gas           28  toyota  highlander hybrid 4wd            a
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2012&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2012 = json.loads(response.text)
highlander_df_2012 = pd.json_normalize(highlander_2012)
highlander_df_2012
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        20  sport utility vehicle               22          4           2.7
# 1        18  sport utility vehicle               20          6           3.5
# 2        17  sport utility vehicle               19          6           3.5
# 3        28  sport utility vehicle               28          6           3.5
#
#   drive fuel_type  highway_mpg    make                  model transmission  \
# 0   fwd       gas           25  toyota         highlander 2wd            a
# 1   fwd       gas           24  toyota         highlander 2wd            a
# 2   awd       gas           22  toyota         highlander 4wd            a
# 3   awd       gas           28  toyota  highlander hybrid 4wd            a
#
#    year
# 0  2012
# 1  2012
# 2  2012
# 3  2012

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2013&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2013 = json.loads(response.text)
highlander_df_2013 = pd.json_normalize(highlander_2013)
highlander_df_2013
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        18     small sport utility vehicle               20          6
# 2        17     small sport utility vehicle               19          6
# 3        28  standard sport utility vehicle               28          6
#
#    displacement drive fuel_type  highway_mpg    make                  model  \
# 0           2.7   fwd       gas           25  toyota         highlander 2wd
# 1           3.5   fwd       gas           24  toyota         highlander 2wd
# 2           3.5   awd       gas           22  toyota         highlander 4wd
# 3           3.5   awd       gas           28  toyota  highlander hybrid 4wd
#
#   transmission  year
# 0            a  2013
# 1            a  2013
# 2            a  2013
# 3            a  2013

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2014&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2014 = json.loads(response.text)
highlander_df_2014 = pd.json_normalize(highlander_2014)
highlander_df_2014
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        19     small sport utility vehicle               21          6
# 2        18  standard sport utility vehicle               20          6
# 3        27  standard sport utility vehicle               28          6
# 4        28  standard sport utility vehicle               28          6
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           2.7   fwd       gas           25  toyota
# 1           3.5   fwd       gas           25  toyota
# 2           3.5   awd       gas           24  toyota
# 3           3.5   awd       gas           28  toyota
# 4           3.5   awd       gas           28  toyota
#
#                            model transmission  year
# 0                 highlander 2wd            a  2014
# 1                 highlander 2wd            a  2014
# 2                 highlander awd            a  2014
# ...

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2015&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2015 = json.loads(response.text)
highlander_df_2015 = pd.json_normalize(highlander_2015)
highlander_df_2015
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        19     small sport utility vehicle               21          6
# 2        18  standard sport utility vehicle               20          6
# 3        27  standard sport utility vehicle               28          6
# 4        28  standard sport utility vehicle               28          6
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           2.7   fwd       gas           25  toyota
# 1           3.5   fwd       gas           25  toyota
# 2           3.5   awd       gas           24  toyota
# 3           3.5   awd       gas           28  toyota
# 4           3.5   awd       gas           28  toyota
#
#                            model transmission  year
# 0                 highlander 2wd            a  2015
# 1                 highlander 2wd            a  2015
# 2                 highlander awd            a  2015
# ...

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2016&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2016 = json.loads(response.text)
highlander_df_2016 = pd.json_normalize(highlander_2016)
highlander_df_2016
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        19     small sport utility vehicle               21          6
# 2        18  standard sport utility vehicle               20          6
# 3        27  standard sport utility vehicle               28          6
# 4        28  standard sport utility vehicle               28          6
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           2.7   fwd       gas           25  toyota
# 1           3.5   fwd       gas           25  toyota
# 2           3.5   awd       gas           24  toyota
# 3           3.5   awd       gas           28  toyota
# 4           3.5   awd       gas           28  toyota
#
#                            model transmission  year
# 0                 highlander 2wd            a  2016
# 1                 highlander 2wd            a  2016
# 2                 highlander awd            a  2016
# ...

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2017&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2017 = json.loads(response.text)
highlander_df_2017 = pd.json_normalize(highlander_2017)
highlander_df_2017
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        21     small sport utility vehicle               23          6
# 2        20     small sport utility vehicle               23          6
# 3        20  standard sport utility vehicle               22          6
# 4        19  standard sport utility vehicle               22          6
# 5        29  standard sport utility vehicle               28          6
# 6        30  standard sport utility vehicle               29          6
# 7        20  standard sport utility vehicle               23          6
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           2.7   fwd       gas           24  toyota
# 1           3.5   fwd       gas           27  toyota
# 2           3.5   fwd       gas           27  toyota
# 3           3.5   awd       gas           26  toyota
# ...

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2018&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2018 = json.loads(response.text)
highlander_df_2018 = pd.json_normalize(highlander_2018)
highlander_df_2018
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        21     small sport utility vehicle               23          6
# 2        20     small sport utility vehicle               23          6
# 3        19  standard sport utility vehicle               22          6
# 4        20  standard sport utility vehicle               22          6
# 5        20  standard sport utility vehicle               23          6
# 6        29  standard sport utility vehicle               28          6
# 7        30  standard sport utility vehicle               29          6
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           2.7   fwd       gas           24  toyota
# 1           3.5   fwd       gas           27  toyota
# 2           3.5   fwd       gas           27  toyota
# 3           3.5   awd       gas           26  toyota
# ...

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2019&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2019 = json.loads(response.text)
highlander_df_2019 = pd.json_normalize(highlander_2019)
highlander_df_2019
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               22          4
# 1        21     small sport utility vehicle               23          6
# 2        20     small sport utility vehicle               23          6
# 3        19  standard sport utility vehicle               22          6
# 4        20  standard sport utility vehicle               22          6
# 5        20  standard sport utility vehicle               23          6
# 6        29  standard sport utility vehicle               28          6
# 7        30  standard sport utility vehicle               29          6
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           2.7   fwd       gas           24  toyota
# 1           3.5   fwd       gas           27  toyota
# 2           3.5   fwd       gas           27  toyota
# 3           3.5   awd       gas           26  toyota
# ...

# %%
model = "highlander"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2020&model=highlander'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
highlander_2020 = json.loads(response.text)
highlander_df_2020 = pd.json_normalize(highlander_2020)
highlander_df_2020
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        20     small sport utility vehicle               23          6
# 1        21     small sport utility vehicle               24          6
# 2        20     small sport utility vehicle               23          6
# 3        36     small sport utility vehicle               36          4
# 4        35  standard sport utility vehicle               35          4
# 5        35  standard sport utility vehicle               35          4
#
#    displacement drive fuel_type  highway_mpg    make  \
# 0           3.5   fwd       gas           28  toyota
# 1           3.5   fwd       gas           29  toyota
# 2           3.5   awd       gas           27  toyota
# 3           2.5   fwd       gas           35  toyota
# 4           2.5   awd       gas           35  toyota
# 5           2.5   awd       gas           34  toyota
#
#                             model transmission  year
# ...

# %%
highlander_df_2010_2020 = pd.concat([highlander_df_2010, highlander_df_2011, highlander_df_2012, highlander_df_2013, highlander_df_2014, highlander_df_2015, highlander_df_2016, highlander_df_2017, highlander_df_2018, highlander_df_2019, highlander_df_2020])
highlander_df_2010_2020
# Out:
#     city_mpg                           class  combination_mpg  cylinders  \
# 0         20           sport utility vehicle               22          4
# 1         18           sport utility vehicle               20          6
# 2         17           sport utility vehicle               19          6
# 3         27           sport utility vehicle               26          6
# 0         20           sport utility vehicle               22          4
# ..       ...                             ...              ...        ...
# 1         21     small sport utility vehicle               24          6
# 2         20     small sport utility vehicle               23          6
# 3         36     small sport utility vehicle               36          4
# 4         35  standard sport utility vehicle               35          4
# 5         35  standard sport utility vehicle               35          4
#
#     displacement drive fuel_type  highway_mpg    make  \
# ...

# %%
highlander_df_2010_2020.to_csv("highlander.csv")

# %%
prices = pd.read_csv("true_car_listings.csv")
prices['Make'] = prices['Make'].str.lower()
prices
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       acura    ILX6-Speed
# 1       acura    ILX5-Speed
# ...

# %%
prices_highlander = prices.loc[(prices["Make"] == "toyota") & (prices["Model"] == "Highlander") | (prices["Model"] == "Highlander4dr") | (prices["Model"] == "HighlanderFWD") | (prices["Model"] == "Highlander2WD")]
prices_highlander
# Out:
#         Price  Year  Mileage          City State                Vin    Make  \
# 765435   9980  2006    61251       Houston    TX  JTEDW21A760011150  toyota
# 767108   5991  2007   142450  Jacksonville    FL  JTEEW21A370045818  toyota
# 767952   8444  2006   115373        Ottawa    IL  JTEEW21A760009094  toyota
# 768362   6866  2007   147247     Thorndale    PA  JTEHW21A570042416  toyota
# 768560   8999  2007   113181       Seymour    CT  JTEHW21AX70041097  toyota
# ...       ...   ...      ...           ...   ...                ...     ...
# 823105  10999  2006   150613      Longmont    CO  JTEEP21A660159727  toyota
# 823371  33998  2015    19685      BEAUMONT    TX  5TDKKRFH5FS109290  toyota
# 823455  36000  2016    29753    Scottsboro    AL  5TDKKRFH4GS142816  toyota
# 823481  31991  2015    34657   Bay Minette    AL  5TDZKRFH5FS118182  toyota
# 823764  99999  2003   259732      Harrison    AR  JTEHF21A130149294  toyota
#
#                 Model
# 765435     Highlander
# ...

# %%
prices_highlander.to_csv("updated_highlander.csv")
