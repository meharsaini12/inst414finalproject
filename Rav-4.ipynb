# %%
import requests
import json 
import pandas as pd

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2010'
response_2010 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2010 = json.loads(response_2010.text)
rav_df_2010 = pd.json_normalize(rav_2010)
rav_df_2010
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        22  sport utility vehicle               24          4           2.5
# 1        19  sport utility vehicle               22          6           3.5
# 2        21  sport utility vehicle               24          4           2.5
# 3        19  sport utility vehicle               21          6           3.5
#
#   drive fuel_type  highway_mpg    make     model transmission  year
# 0   fwd       gas           28  toyota  rav4 2wd            a  2010
# 1   fwd       gas           27  toyota  rav4 2wd            a  2010
# 2   awd       gas           27  toyota  rav4 4wd            a  2010
# 3   awd       gas           26  toyota  rav4 4wd            a  2010

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2011'
response_2011 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2011 = json.loads(response_2011.text)
rav_df_2011 = pd.json_normalize(rav_2011)
rav_df_2011
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        21  sport utility vehicle               24          4           2.5
# 1        19  sport utility vehicle               22          6           3.5
# 2        21  sport utility vehicle               23          4           2.5
# 3        19  sport utility vehicle               21          6           3.5
#
#   drive fuel_type  highway_mpg    make     model transmission  year
# 0   fwd       gas           28  toyota  rav4 2wd            a  2011
# 1   fwd       gas           26  toyota  rav4 2wd            a  2011
# 2   awd       gas           27  toyota  rav4 4wd            a  2011
# 3   awd       gas           25  toyota  rav4 4wd            a  2011

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2012'
response_2012 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2012 = json.loads(response_2012.text)
rav_df_2012 = pd.json_normalize(rav_2012)
rav_df_2012
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        21  sport utility vehicle               24        4.0           2.5
# 1        19  sport utility vehicle               22        6.0           3.5
# 2        21  sport utility vehicle               23        4.0           2.5
# 3        19  sport utility vehicle               22        6.0           3.5
# 4        78  sport utility vehicle               76        NaN           NaN
#
#   drive    fuel_type  highway_mpg    make     model transmission  year
# 0   fwd          gas           28  toyota  rav4 2wd            a  2012
# 1   fwd          gas           26  toyota  rav4 2wd            a  2012
# 2   awd          gas           27  toyota  rav4 4wd            a  2012
# 3   awd          gas           26  toyota  rav4 4wd            a  2012
# 4   fwd  electricity           74  toyota   rav4 ev            a  2012

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2013'
response_2013 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2013 = json.loads(response_2013.text)
rav_df_2013 = pd.json_normalize(rav_2013)
rav_df_2013
# Out:
#    city_mpg                        class  combination_mpg drive    fuel_type  \
# 0        78  small sport utility vehicle               76   fwd  electricity
# 1        23  small sport utility vehicle               26   fwd          gas
# 2        22  small sport utility vehicle               25   awd          gas
# 3        22  small sport utility vehicle               25   awd          gas
#
#    highway_mpg    make             model transmission  year  cylinders  \
# 0           74  toyota           rav4 ev            a  2013        NaN
# 1           30  toyota          rav4 2wd            a  2013        4.0
# 2           28  toyota          rav4 awd            a  2013        4.0
# 3           29  toyota  rav4 limited awd            a  2013        4.0
#
#    displacement
# 0           NaN
# 1           2.5
# 2           2.5
# 3           2.5

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2014'
response_2014 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2014 = json.loads(response_2014.text)
rav_df_2014 = pd.json_normalize(rav_2014)
rav_df_2014
# Out:
#    city_mpg                        class  combination_mpg drive    fuel_type  \
# 0        78  small sport utility vehicle               76   fwd  electricity
# 1        23  small sport utility vehicle               26   fwd          gas
# 2        22  small sport utility vehicle               25   awd          gas
# 3        22  small sport utility vehicle               24   awd          gas
#
#    highway_mpg    make             model transmission  year  cylinders  \
# 0           74  toyota           rav4 ev            a  2014        NaN
# 1           30  toyota              rav4            a  2014        4.0
# 2           28  toyota          rav4 awd            a  2014        4.0
# 3           28  toyota  rav4 limited awd            a  2014        4.0
#
#    displacement
# 0           NaN
# 1           2.5
# 2           2.5
# 3           2.5

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2015'
response_2015 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2015 = json.loads(response_2015.text)
rav_df_2015 = pd.json_normalize(rav_2015)
rav_df_2015
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               26          4
# 1        22  small sport utility vehicle               25          4
# 2        22  small sport utility vehicle               24          4
# 3        23  small sport utility vehicle               26          4
#
#    displacement drive fuel_type  highway_mpg    make             model  \
# 0           2.5   fwd       gas           30  toyota              rav4
# 1           2.5   awd       gas           28  toyota          rav4 awd
# 2           2.5   awd       gas           28  toyota  rav4 limited awd
# 3           2.5   fwd       gas           30  toyota       rav4 le/xle
#
#   transmission  year
# 0            a  2015
# 1            a  2015
# 2            a  2015
# 3            a  2015

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2016'
response_2016 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2016 = json.loads(response_2016.text)
rav_df_2016 = pd.json_normalize(rav_2016)
rav_df_2016
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               25          4
# 1        23  small sport utility vehicle               26          4
# 2        22  small sport utility vehicle               25          4
# 3        22  small sport utility vehicle               24          4
# 4        34  small sport utility vehicle               32          4
#
#    displacement drive fuel_type  highway_mpg    make                    model  \
# 0           2.5   fwd       gas           29  toyota                     rav4
# 1           2.5   fwd       gas           30  toyota              rav4 le/xle
# 2           2.5   awd       gas           28  toyota                 rav4 awd
# 3           2.5   awd       gas           28  toyota  rav4 limited awd/se awd
# 4           2.5   awd       gas           30  toyota          rav4 hybrid awd
#
#   transmission  year
# 0            a  2016
# 1            a  2016
# ...

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2017'
response_2017 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2017 = json.loads(response_2017.text)
rav_df_2017 = pd.json_normalize(rav_2017)
rav_df_2017
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               25          4
# 1        23  small sport utility vehicle               26          4
# 2        22  small sport utility vehicle               25          4
# 3        22  small sport utility vehicle               24          4
# 4        34  small sport utility vehicle               32          4
#
#    displacement drive fuel_type  highway_mpg    make                    model  \
# 0           2.5   fwd       gas           29  toyota                     rav4
# 1           2.5   fwd       gas           30  toyota              rav4 le/xle
# 2           2.5   awd       gas           28  toyota                 rav4 awd
# 3           2.5   awd       gas           28  toyota  rav4 limited awd/se awd
# 4           2.5   awd       gas           30  toyota          rav4 hybrid awd
#
#   transmission  year
# 0            a  2017
# 1            a  2017
# ...

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2018'
response_2018 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2018 = json.loads(response_2018.text)
rav_df_2018 = pd.json_normalize(rav_2018)
rav_df_2018
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               25          4
# 1        23  small sport utility vehicle               26          4
# 2        22  small sport utility vehicle               25          4
# 3        22  small sport utility vehicle               24          4
# 4        34  small sport utility vehicle               32          4
#
#    displacement drive fuel_type  highway_mpg    make                    model  \
# 0           2.5   fwd       gas           29  toyota                     rav4
# 1           2.5   fwd       gas           30  toyota              rav4 le/xle
# 2           2.5   awd       gas           28  toyota                 rav4 awd
# 3           2.5   awd       gas           28  toyota  rav4 limited awd/se awd
# 4           2.5   awd       gas           30  toyota          rav4 hybrid awd
#
#   transmission  year
# 0            a  2018
# 1            a  2018
# ...

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2019'
response_2019 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2019 = json.loads(response_2019.text)
rav_df_2019 = pd.json_normalize(rav_2019)
rav_df_2019
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        26  small sport utility vehicle               30          4
# 1        25  small sport utility vehicle               28          4
# 2        27  small sport utility vehicle               30          4
# 3        41  small sport utility vehicle               40          4
#
#    displacement drive fuel_type  highway_mpg    make            model  \
# 0           2.5   fwd       gas           35  toyota             rav4
# 1           2.5   awd       gas           33  toyota         rav4 awd
# 2           2.5   awd       gas           34  toyota         rav4 awd
# 3           2.5   awd       gas           38  toyota  rav4 hybrid awd
#
#   transmission  year
# 0            a  2019
# 1            a  2019
# 2            a  2019
# 3            a  2019

# %%
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&model=rav4&year=2020'
response_2020 = requests.get(api_url, headers={'X-Api-Key': '3o7SMKTDD3BVFWp3gnX79g==r0BgYjtmnGEit752'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 22, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 28, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 22, "cylinders": 6, "displacement": 3.5, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 2wd", "transmission": "a", "year": 2010}, {"city_mpg": 21, "class": "sport utility vehicle", "combination_mpg": 24, "cylinders": 4, "displacement": 2.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}, {"city_mpg": 19, "class": "sport utility vehicle", "combination_mpg": 21, "cylinders": 6, "displacement": 3.5, "drive": "awd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "rav4 4wd", "transmission": "a", "year": 2010}]

# %%
rav_2020 = json.loads(response_2020.text)
rav_df_2020 = pd.json_normalize(rav_2020)
rav_df_2020
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        27  small sport utility vehicle               30          4
# 1        28  small sport utility vehicle               30          4
# 2        25  small sport utility vehicle               28          4
# 3        27  small sport utility vehicle               29          4
# 4        41  small sport utility vehicle               40          4
# 5        25  small sport utility vehicle               27          4
# 6        27  small sport utility vehicle               30          4
#
#    displacement drive fuel_type  highway_mpg    make                 model  \
# 0           2.5   fwd       gas           35  toyota                  rav4
# 1           2.5   fwd       gas           35  toyota                  rav4
# 2           2.5   awd       gas           33  toyota              rav4 awd
# 3           2.5   awd       gas           33  toyota              rav4 awd
# ...

# %%
rav4_df = pd.concat([rav_df_2010,rav_df_2011,rav_df_2012,rav_df_2013,rav_df_2014,rav_df_2015,rav_df_2016,rav_df_2017,rav_df_2018,rav_df_2019,rav_df_2020])

# %%
rav4_df.shape[0]
# Out:
# 51

# %%
rav4_df.to_csv("rav4.csv")

# %%
prices = pd.read_csv("/Users/johnspurrier/Downloads/tc20171021.csv",on_bad_lines='skip')
prices['Make'] = prices['Make'].str.lower()
prices['Model'] = prices['Model'].str.lower()
prices
# Out:
#               Id  Price  Year  Mileage            City State  \
# 0              1  16472  2015    18681  Jefferson City    MO
# 1              2  15749  2015    27592        Highland    IN
# 2              3  16998  2015    13650           Boone    NC
# 3              4  15777  2015    25195     New Orleans    LA
# 4              5  16784  2015    22800       Las Vegas    NV
# ...          ...    ...   ...      ...             ...   ...
# 1216245  1233038  79900  2017       25    East Hanover    NJ
# 1216246  1233039  80895  2017       10    Corte Madera    CA
# 1216247  1233040  68755  2018     2500       Englewood    NJ
# 1216248  1233041  72260  2017     3201       Englewood    NJ
# 1216249  1233042  60240  2017     8342     San Leandro    CA
#
#                        Vin   Make              Model
# 0        KL4CJBSBXFB267643  buick  encoreconvenience
# 1        KL4CJASB5FB245057  buick          encorefwd
# 2        KL4CJCSB0FB264921  buick      encoreleather
# ...

# %%
prices_rav4 = prices.loc[(prices["Make"] == "toyota") & (prices["Model"] == "rav4") |(prices["Model"] == "rav42wd")
                        |(prices["Model"] == "rav44wd")| (prices["Model"] == "rav4awd")|(prices["Model"] == "rav4ev")
                        |(prices["Model"] == "rav4le")|(prices["Model"] == "rav4hybrid")]
prices_rav4
# Out:
#               Id  Price  Year  Mileage           City State  \
# 323268    327318  11868  2010    36940  Pinellas Park    FL
# 323506    327556  15495  2016    29234      Greatneck    NY
# 323529    327579  15900  2014    32066          Hemet    CA
# 323704    327754  13995  2013    38906    Midway City    CA
# 323718    327768  16980  2016    16151      Greatneck    NY
# ...          ...    ...   ...      ...            ...   ...
# 1182942  1199638  24000  2017     1993     Scottsboro    AL
# 1183127  1199825  16995  2014    73680   Marble Falls    TX
# 1184509  1201248  13288  2010   107527     Healdsburg    CA
# 1184740  1201482  18500  2012    71896  Fuquay-Varina    NC
# 1187188  1203976   7875  2007   234688        Hanover    PA
#
#                        Vin    Make    Model
# 323268   2T3BF4DV9AW074535  toyota  rav44wd
# 323506   JTMBFREV0GJ062373  toyota  rav4awd
# 323529   2T3YL4DV4EW002733  toyota     rav4
# 323704   2T3YL4DV7DW001669  toyota     rav4
# ...

# %%
prices_rav4.to_csv("rav4_prices.csv")
