# %%
import requests
import json 
import pandas as pd

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2010&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2010_json = json.loads(response.text)
equinox2010_df = pd.json_normalize(equinox2010_json)

equinox2010_df
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        22  sport utility vehicle               26          4           2.4
# 1        20  sport utility vehicle               23          4           2.4
# 2        17  sport utility vehicle               20          6           3.0
# 3        17  sport utility vehicle               20          6           3.0
#
#   drive fuel_type  highway_mpg       make        model transmission  year
# 0   fwd       gas           32  chevrolet  equinox fwd            a  2010
# 1   awd       gas           29  chevrolet  equinox awd            a  2010
# 2   fwd       gas           25  chevrolet  equinox fwd            a  2010
# 3   awd       gas           24  chevrolet  equinox awd            a  2010

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2011&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2011_json = json.loads(response.text)
equinox2011_df = pd.json_normalize(equinox2011_json)

equinox2011_df
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        22  sport utility vehicle               26          4           2.4
# 1        20  sport utility vehicle               23          4           2.4
# 2        16  sport utility vehicle               19          6           3.0
# 3        17  sport utility vehicle               20          6           3.0
# 4        16  sport utility vehicle               19          6           3.0
# 5        16  sport utility vehicle               19          6           3.0
#
#   drive fuel_type  highway_mpg       make        model transmission  year
# 0   fwd       gas           31  chevrolet  equinox fwd            a  2011
# 1   awd       gas           28  chevrolet  equinox awd            a  2011
# 2   fwd       gas           23  chevrolet  equinox fwd            a  2011
# 3   fwd       gas           24  chevrolet  equinox fwd            a  2011
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2012&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2012_json = json.loads(response.text)
equinox2012_df = pd.json_normalize(equinox2012_json)

equinox2012_df
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        17  sport utility vehicle               20          6           3.0
# 1        22  sport utility vehicle               26          4           2.4
# 2        17  sport utility vehicle               20          6           3.0
# 3        20  sport utility vehicle               23          4           2.4
# 4        16  sport utility vehicle               19          6           3.0
# 5        16  sport utility vehicle               19          6           3.0
# 6        22  sport utility vehicle               26          4           2.4
# 7        20  sport utility vehicle               23          4           2.4
#
#   drive fuel_type  highway_mpg       make        model transmission  year
# 0   fwd       gas           24  chevrolet  equinox fwd            a  2012
# 1   fwd       gas           31  chevrolet  equinox fwd            a  2012
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2013&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2013_json = json.loads(response.text)
equinox2013_df = pd.json_normalize(equinox2013_json)

equinox2013_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          4
# 1        20  small sport utility vehicle               23          4
# 2        17  small sport utility vehicle               20          6
# 3        22  small sport utility vehicle               26          4
# 4        17  small sport utility vehicle               20          6
# 5        22  small sport utility vehicle               26          4
# 6        16  small sport utility vehicle               19          6
# 7        16  small sport utility vehicle               19          6
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           2.4   awd       gas           28  chevrolet  equinox awd
# 1           2.4   awd       gas           28  chevrolet  equinox awd
# 2           3.6   fwd       gas           24  chevrolet  equinox fwd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2014&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2014_json = json.loads(response.text)
equinox2014_df = pd.json_normalize(equinox2014_json)

equinox2014_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        17  small sport utility vehicle               19          6
# 1        22  small sport utility vehicle               26          4
# 2        17  small sport utility vehicle               20          6
# 3        16  small sport utility vehicle               19          6
# 4        20  small sport utility vehicle               23          4
# 5        20  small sport utility vehicle               23          4
# 6        16  small sport utility vehicle               19          6
# 7        22  small sport utility vehicle               26          4
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           3.6   fwd       gas           24  chevrolet  equinox fwd
# 1           2.4   fwd       gas           31  chevrolet  equinox fwd
# 2           3.6   fwd       gas           24  chevrolet  equinox fwd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2015&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2015_json = json.loads(response.text)
equinox2015_df = pd.json_normalize(equinox2015_json)

equinox2015_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        22  small sport utility vehicle               26          4
# 1        17  small sport utility vehicle               19          6
# 2        22  small sport utility vehicle               26          4
# 3        16  small sport utility vehicle               19          6
# 4        20  small sport utility vehicle               23          4
# 5        20  small sport utility vehicle               23          4
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           2.4   fwd       gas           31  chevrolet  equinox fwd
# 1           3.6   fwd       gas           24  chevrolet  equinox fwd
# 2           2.4   fwd       gas           31  chevrolet  equinox fwd
# 3           3.6   awd       gas           23  chevrolet  equinox awd
# 4           2.4   awd       gas           28  chevrolet  equinox awd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2016&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2016_json = json.loads(response.text)
equinox2016_df = pd.json_normalize(equinox2016_json)

equinox2016_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          4
# 1        20  small sport utility vehicle               23          4
# 2        22  small sport utility vehicle               26          4
# 3        22  small sport utility vehicle               26          4
# 4        16  small sport utility vehicle               18          6
# 5        17  small sport utility vehicle               20          6
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           2.4   awd       gas           28  chevrolet  equinox awd
# 1           2.4   awd       gas           28  chevrolet  equinox awd
# 2           2.4   fwd       gas           31  chevrolet  equinox fwd
# 3           2.4   fwd       gas           31  chevrolet  equinox fwd
# 4           3.6   awd       gas           23  chevrolet  equinox awd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2017&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2017_json = json.loads(response.text)
equinox2017_df = pd.json_normalize(equinox2017_json)

equinox2017_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          4
# 1        21  small sport utility vehicle               25          4
# 2        17  small sport utility vehicle               20          6
# 3        21  small sport utility vehicle               25          4
# 4        16  small sport utility vehicle               18          6
# 5        20  small sport utility vehicle               23          4
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           2.4   awd       gas           28  chevrolet  equinox awd
# 1           2.4   fwd       gas           31  chevrolet  equinox fwd
# 2           3.6   fwd       gas           24  chevrolet  equinox fwd
# 3           2.4   fwd       gas           31  chevrolet  equinox fwd
# 4           3.6   awd       gas           23  chevrolet  equinox awd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2018&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2018_json = json.loads(response.text)
equinox2018_df = pd.json_normalize(equinox2018_json)

equinox2018_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        26  small sport utility vehicle               28          4
# 1        24  small sport utility vehicle               26          4
# 2        22  small sport utility vehicle               25          4
# 3        22  small sport utility vehicle               24          4
# 4        28  small sport utility vehicle               32          4
# 5        28  small sport utility vehicle               32          4
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           1.5   fwd       gas           32  chevrolet  equinox fwd
# 1           1.5   awd       gas           30  chevrolet  equinox awd
# 2           2.0   fwd       gas           29  chevrolet  equinox fwd
# 3           2.0   awd       gas           28  chevrolet  equinox awd
# 4           1.6   fwd    diesel           39  chevrolet  equinox fwd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2019&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2019_json = json.loads(response.text)
equinox2019_df = pd.json_normalize(equinox2019_json)

equinox2019_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        22  small sport utility vehicle               25          4
# 1        26  small sport utility vehicle               28          4
# 2        25  small sport utility vehicle               27          4
# 3        22  small sport utility vehicle               24          4
# 4        28  small sport utility vehicle               32          4
# 5        28  small sport utility vehicle               32          4
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           2.0   fwd       gas           29  chevrolet  equinox fwd
# 1           1.5   fwd       gas           32  chevrolet  equinox fwd
# 2           1.5   awd       gas           30  chevrolet  equinox awd
# 3           2.0   awd       gas           28  chevrolet  equinox awd
# 4           1.6   awd    diesel           38  chevrolet  equinox awd
# ...

# %%
model = 'equinox'
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2020&model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'ZCdETropEXWOtXAjrg7ceQ==jfg7IuXZLUUuwjMi'})

equinox2020_json = json.loads(response.text)
equinox2020_df = pd.json_normalize(equinox2020_json)

equinox2020_df
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        26  small sport utility vehicle               28          4
# 1        22  small sport utility vehicle               25          4
# 2        25  small sport utility vehicle               27          4
# 3        22  small sport utility vehicle               24          4
#
#    displacement drive fuel_type  highway_mpg       make        model  \
# 0           1.5   fwd       gas           31  chevrolet  equinox fwd
# 1           2.0   fwd       gas           29  chevrolet  equinox fwd
# 2           1.5   awd       gas           30  chevrolet  equinox awd
# 3           2.0   awd       gas           28  chevrolet  equinox awd
#
#   transmission  year
# 0            a  2020
# 1            a  2020
# 2            a  2020
# 3            a  2020

# %%
equinox_df = pd.concat([equinox2010_df, equinox2011_df, equinox2012_df, equinox2013_df, 
                        equinox2014_df, equinox2015_df, equinox2016_df, equinox2017_df, equinox2018_df, 
                        equinox2019_df, equinox2020_df])
equinox_df
# Out:
#     city_mpg                        class  combination_mpg  cylinders  \
# 0         22        sport utility vehicle               26          4
# 1         20        sport utility vehicle               23          4
# 2         17        sport utility vehicle               20          6
# 3         17        sport utility vehicle               20          6
# 0         22        sport utility vehicle               26          4
# ..       ...                          ...              ...        ...
# 5         28  small sport utility vehicle               32          4
# 0         26  small sport utility vehicle               28          4
# 1         22  small sport utility vehicle               25          4
# 2         25  small sport utility vehicle               27          4
# 3         22  small sport utility vehicle               24          4
#
#     displacement drive fuel_type  highway_mpg       make        model  \
# ...

# %%
equinox_df.to_csv("e.csv")
