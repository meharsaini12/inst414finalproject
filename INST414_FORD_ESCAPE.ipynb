# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl.workbook import Workbook
import statistics 
import os

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2010&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2010 = json.loads(response.text)
escape_df_2010 = pd.json_normalize(escape_2010)
escape_df_2010
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        21  sport utility vehicle               23          4           2.5
# 1        22  sport utility vehicle               24          4           2.5
# 2        19  sport utility vehicle               21          6           3.0
# 3        34  sport utility vehicle               32          4           2.5
# 4        20  sport utility vehicle               22          4           2.5
# 5        18  sport utility vehicle               20          6           3.0
# 6        30  sport utility vehicle               29          4           2.5
#
#   drive fuel_type  highway_mpg  make              model transmission  year
# 0   fwd       gas           28  ford         escape fwd            a  2010
# 1   fwd       gas           28  ford         escape fwd            m  2010
# 2   fwd       gas           25  ford     escape fwd ffv            a  2010
# ...

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2011&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2011 = json.loads(response.text)
escape_df_2011 = pd.json_normalize(escape_2011)
escape_df_2011
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        23  sport utility vehicle               25          4           2.5
# 1        34  sport utility vehicle               32          4           2.5
# 2        19  sport utility vehicle               21          6           3.0
# 3        21  sport utility vehicle               23          4           2.5
# 4        30  sport utility vehicle               29          4           2.5
# 5        18  sport utility vehicle               20          6           3.0
# 6        20  sport utility vehicle               22          4           2.5
#
#   drive fuel_type  highway_mpg  make              model transmission  year
# 0   fwd       gas           28  ford         escape fwd            m  2011
# 1   fwd       gas           30  ford  escape hybrid fwd            a  2011
# 2   fwd       gas           25  ford     escape fwd ffv            a  2011
# ...

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2012&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2012 = json.loads(response.text)
escape_df_2012 = pd.json_normalize(escape_2012)
escape_df_2012
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        34  sport utility vehicle               32          4           2.5
# 1        19  sport utility vehicle               21          6           3.0
# 2        21  sport utility vehicle               23          4           2.5
# 3        23  sport utility vehicle               25          4           2.5
# 4        30  sport utility vehicle               29          4           2.5
# 5        18  sport utility vehicle               20          6           3.0
# 6        20  sport utility vehicle               23          4           2.5
#
#   drive fuel_type  highway_mpg  make              model transmission  year
# 0   fwd       gas           30  ford  escape hybrid fwd            a  2012
# 1   fwd       gas           25  ford     escape fwd ffv            a  2012
# 2   fwd       gas           27  ford         escape fwd            a  2012
# ...

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2013&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2013 = json.loads(response.text)
escape_df_2013 = pd.json_normalize(escape_2013)
escape_df_2013
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        22  small sport utility vehicle               25          4
# 1        22  small sport utility vehicle               24          4
# 2        21  small sport utility vehicle               24          4
# 3        22  small sport utility vehicle               25          4
# 4        23  small sport utility vehicle               26          4
#
#    displacement drive fuel_type  highway_mpg  make       model transmission  \
# 0           2.5   fwd       gas           30  ford  escape fwd            a
# 1           2.0   fwd       gas           29  ford  escape fwd            a
# 2           2.0   awd       gas           28  ford  escape awd            a
# 3           1.6   awd       gas           29  ford  escape awd            a
# 4           1.6   fwd       gas           32  ford  escape fwd            a
#
#    year
# 0  2013
# 1  2013
# 2  2013
# 3  2013
# 4  2013

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2014&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2014 = json.loads(response.text)
escape_df_2014 = pd.json_normalize(escape_2014)
escape_df_2014
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               26          4
# 1        22  small sport utility vehicle               24          4
# 2        22  small sport utility vehicle               25          4
# 3        21  small sport utility vehicle               24          4
# 4        22  small sport utility vehicle               25          4
#
#    displacement drive fuel_type  highway_mpg  make       model transmission  \
# 0           1.6   fwd       gas           31  ford  escape fwd            a
# 1           2.0   fwd       gas           29  ford  escape fwd            a
# 2           2.5   fwd       gas           30  ford  escape fwd            a
# 3           2.0   awd       gas           28  ford  escape awd            a
# 4           1.6   awd       gas           29  ford  escape awd            a
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2015&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2015 = json.loads(response.text)
escape_df_2015 = pd.json_normalize(escape_2015)
escape_df_2015
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               26          4
# 1        21  small sport utility vehicle               24          4
# 2        21  small sport utility vehicle               25          4
# 3        22  small sport utility vehicle               25          4
# 4        21  small sport utility vehicle               23          4
#
#    displacement drive fuel_type  highway_mpg  make       model transmission  \
# 0           1.6   fwd       gas           31  ford  escape fwd            a
# 1           2.0   fwd       gas           29  ford  escape fwd            a
# 2           2.5   fwd       gas           30  ford  escape fwd            a
# 3           1.6   awd       gas           29  ford  escape awd            a
# 4           2.0   awd       gas           28  ford  escape awd            a
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2016&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2016 = json.loads(response.text)
escape_df_2016 = pd.json_normalize(escape_2016)
escape_df_2016
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               26          4
# 1        21  small sport utility vehicle               24          4
# 2        22  small sport utility vehicle               25          4
# 3        22  small sport utility vehicle               25          4
# 4        21  small sport utility vehicle               23          4
#
#    displacement drive fuel_type  highway_mpg  make       model transmission  \
# 0           1.6   fwd       gas           31  ford  escape fwd            a
# 1           2.0   fwd       gas           29  ford  escape fwd            a
# 2           2.5   fwd       gas           30  ford  escape fwd            a
# 3           1.6   awd       gas           29  ford  escape awd            a
# 4           2.0   awd       gas           28  ford  escape awd            a
#
#    year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2017&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2017 = json.loads(response.text)
escape_df_2017 = pd.json_normalize(escape_2017)
escape_df_2017
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        21  small sport utility vehicle               24          4
# 1        23  small sport utility vehicle               26          4
# 2        22  small sport utility vehicle               25          4
# 3        21  small sport utility vehicle               24          4
# 4        20  small sport utility vehicle               23          4
# 5        22  small sport utility vehicle               24          4
#
#    displacement drive fuel_type  highway_mpg  make           model  \
# 0           2.5   fwd       gas           29  ford      escape fwd
# 1           1.5   fwd       gas           30  ford      escape fwd
# 2           2.0   fwd       gas           29  ford      escape fwd
# 3           2.5   fwd       gas           29  ford  escape fwd ffv
# 4           2.0   awd       gas           27  ford      escape awd
# 5           1.5   awd       gas           28  ford      escape awd
#
# ...

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2018&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2018 = json.loads(response.text)
escape_df_2018 = pd.json_normalize(escape_2018)
escape_df_2018
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        23  small sport utility vehicle               26          4
# 1        21  small sport utility vehicle               24          4
# 2        21  small sport utility vehicle               24          4
# 3        21  small sport utility vehicle               24          4
# 4        22  small sport utility vehicle               24          4
# 5        20  small sport utility vehicle               23          4
#
#    displacement drive fuel_type  highway_mpg  make           model  \
# 0           1.5   fwd       gas           30  ford      escape fwd
# 1           2.0   fwd       gas           28  ford      escape fwd
# 2           2.5   fwd       gas           29  ford  escape fwd ffv
# 3           2.5   fwd       gas           29  ford      escape fwd
# 4           1.5   awd       gas           28  ford      escape awd
# 5           2.0   awd       gas           27  ford      escape awd
#
# ...

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2019&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2019 = json.loads(response.text)
escape_df_2019 = pd.json_normalize(escape_2019)
escape_df_2019
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        21  small sport utility vehicle               24          4
# 1        21  small sport utility vehicle               24          4
# 2        22  small sport utility vehicle               25          4
# 3        23  small sport utility vehicle               26          4
# 4        22  small sport utility vehicle               24          4
# 5        21  small sport utility vehicle               23          4
#
#    displacement drive fuel_type  highway_mpg  make           model  \
# 0           2.5   fwd       gas           29  ford  escape fwd ffv
# 1           2.5   fwd       gas           29  ford      escape fwd
# 2           2.0   fwd       gas           29  ford      escape fwd
# 3           1.5   fwd       gas           30  ford      escape fwd
# 4           1.5   awd       gas           28  ford      escape awd
# 5           2.0   awd       gas           27  ford      escape awd
#
# ...

# %%
model = "escape"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2020&model=escape'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
escape_2020 = json.loads(response.text)
escape_df_2020 = pd.json_normalize(escape_2020)
escape_df_2020
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        27  small sport utility vehicle               30          3
# 1        44  small sport utility vehicle               41          4
# 2        23  small sport utility vehicle               26          4
# 3        26  small sport utility vehicle               28          3
# 4        43  small sport utility vehicle               40          4
# 5        43  small sport utility vehicle               41          4
#
#    displacement drive fuel_type  highway_mpg  make            model  \
# 0           1.5   fwd       gas           33  ford       escape fwd
# 1           2.5   fwd       gas           37  ford   escape fwd hev
# 2           2.0   awd       gas           31  ford       escape awd
# 3           1.5   awd       gas           31  ford       escape awd
# 4           2.5   4wd       gas           37  ford   escape awd hev
# 5           2.5   fwd       gas           38  ford  escape fwd phev
#
# ...

# %%
escape_df_2010_2020 = pd.concat([escape_df_2010, escape_df_2011, escape_df_2012, escape_df_2013, escape_df_2014, escape_df_2015, escape_df_2016, escape_df_2017, escape_df_2018, escape_df_2019, escape_df_2020])
escape_df_2010_2020
# Out:
#     city_mpg                        class  combination_mpg  cylinders  \
# 0         21        sport utility vehicle               23          4
# 1         22        sport utility vehicle               24          4
# 2         19        sport utility vehicle               21          6
# 3         34        sport utility vehicle               32          4
# 4         20        sport utility vehicle               22          4
# ..       ...                          ...              ...        ...
# 1         44  small sport utility vehicle               41          4
# 2         23  small sport utility vehicle               26          4
# 3         26  small sport utility vehicle               28          3
# 4         43  small sport utility vehicle               40          4
# 5         43  small sport utility vehicle               41          4
#
#     displacement drive fuel_type  highway_mpg  make              model  \
# ...

# %%
escape_df_2010_2020.to_csv("escape.csv")

# %%
prices = pd.read_csv("true_car_listings.csv")
prices['Make'] = prices['Make'].str.lower()
prices
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       acura    ILX6-Speed
# 1       acura    ILX5-Speed
# ...

# %%
prices_escape = prices.loc[(prices["Make"] == "ford") & (prices["Model"] == "EscapeFWD") | (prices["Model"] == "Escape4dr")]
prices_escape
# Out:
#         Price  Year  Mileage         City State                Vin  Make  \
# 242821   8495  2012    30519     Columbia    SC  1FMCU0C71CKC76640  ford
# 243829  13500  2015    23510  Leavenworth    KS  1FMCU0F72FUB31711  ford
# 243930  16885  2017     6045       Shelby    NC  1FMCU0F7XHUA19385  ford
# 244180  14288  2016    13974       Stuart    FL  1FMCU0F74GUB11820  ford
# 245065  10999  2015    34228      Phoenix    AZ  1FMCU0F77FUB31395  ford
# ...       ...   ...      ...          ...   ...                ...   ...
# 342262   4500  2003   133287       Topeka    KS  1FMYU03193KC35562  ford
# 343111  23995  2016    13391        Bronx    NY  1FMCU0F72GUB83874  ford
# 344240   3995  2005   185951    Bethlehem    PA  1FMCU96H05KC07224  ford
# 344695  29700  2017     7600      Bel Air    MD  1FMCU0JD2HUA69923  ford
# 346182   4000  2005   232536   New Castle    PA  1FMYU93175KA87807  ford
#
#             Model
# 242821  EscapeFWD
# 243829  EscapeFWD
# 243930  EscapeFWD
# ...
