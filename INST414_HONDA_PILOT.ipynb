# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl.workbook import Workbook
import statistics 
import os

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2010&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2010 = json.loads(response.text)
pilot_df_2010 = pd.json_normalize(pilot_2010)
pilot_df_2010
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        17  sport utility vehicle               19          6           3.5
# 1        16  sport utility vehicle               18          6           3.5
#
#   drive fuel_type  highway_mpg   make      model transmission  year
# 0   fwd       gas           23  honda  pilot 2wd            a  2010
# 1   awd       gas           22  honda  pilot 4wd            a  2010

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2011&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2011 = json.loads(response.text)
pilot_df_2011 = pd.json_normalize(pilot_2011)
pilot_df_2011
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        17  sport utility vehicle               19          6           3.5
# 1        16  sport utility vehicle               18          6           3.5
#
#   drive fuel_type  highway_mpg   make      model transmission  year
# 0   fwd       gas           23  honda  pilot 2wd            a  2011
# 1   awd       gas           22  honda  pilot 4wd            a  2011

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2012&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2012 = json.loads(response.text)
pilot_df_2012 = pd.json_normalize(pilot_2012)
pilot_df_2012
# Out:
#    city_mpg                  class  combination_mpg  cylinders  displacement  \
# 0        18  sport utility vehicle               20          6           3.5
# 1        17  sport utility vehicle               20          6           3.5
#
#   drive fuel_type  highway_mpg   make      model transmission  year
# 0   fwd       gas           25  honda  pilot 2wd            a  2012
# 1   awd       gas           24  honda  pilot 4wd            a  2012

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2013&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2013 = json.loads(response.text)
pilot_df_2013 = pd.json_normalize(pilot_2013)
pilot_df_2013
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        18     small sport utility vehicle               20          6
# 1        17  standard sport utility vehicle               20          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           25  honda  pilot 2wd            a
# 1           3.5   awd       gas           24  honda  pilot 4wd            a
#
#    year
# 0  2013
# 1  2013

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2014&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2014 = json.loads(response.text)
pilot_df_2014 = pd.json_normalize(pilot_2014)
pilot_df_2014
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        18  small sport utility vehicle               20          6
# 1        17  small sport utility vehicle               20          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           25  honda  pilot 2wd            a
# 1           3.5   awd       gas           24  honda  pilot 4wd            a
#
#    year
# 0  2014
# 1  2014

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2015&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2015 = json.loads(response.text)
pilot_df_2015 = pd.json_normalize(pilot_2015)
pilot_df_2015
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        18  small sport utility vehicle               20          6
# 1        17  small sport utility vehicle               20          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           25  honda  pilot 2wd            a
# 1           3.5   awd       gas           24  honda  pilot 4wd            a
#
#    year
# 0  2015
# 1  2015

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2016&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2016 = json.loads(response.text)
pilot_df_2016 = pd.json_normalize(pilot_2016)
pilot_df_2016
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          6
# 1        19  small sport utility vehicle               22          6
# 2        19  small sport utility vehicle               22          6
# 3        18  small sport utility vehicle               21          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           27  honda  pilot 2wd            a
# 1           3.5   fwd       gas           27  honda  pilot 2wd            a
# 2           3.5   awd       gas           26  honda  pilot 4wd            a
# 3           3.5   awd       gas           25  honda  pilot 4wd            a
#
#    year
# 0  2016
# 1  2016
# 2  2016
# 3  2016

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2017&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2017 = json.loads(response.text)
pilot_df_2017 = pd.json_normalize(pilot_2017)
pilot_df_2017
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          6
# 1        19  small sport utility vehicle               22          6
# 2        19  small sport utility vehicle               22          6
# 3        18  small sport utility vehicle               21          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           27  honda  pilot fwd            a
# 1           3.5   fwd       gas           27  honda  pilot fwd            a
# 2           3.5   awd       gas           26  honda  pilot awd            a
# 3           3.5   awd       gas           26  honda  pilot awd            a
#
#    year
# 0  2017
# 1  2017
# 2  2017
# 3  2017

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2018&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2018 = json.loads(response.text)
pilot_df_2018 = pd.json_normalize(pilot_2018)
pilot_df_2018
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          6
# 1        19  small sport utility vehicle               22          6
# 2        19  small sport utility vehicle               22          6
# 3        18  small sport utility vehicle               21          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           27  honda  pilot fwd            a
# 1           3.5   fwd       gas           27  honda  pilot fwd            a
# 2           3.5   awd       gas           26  honda  pilot awd            a
# 3           3.5   awd       gas           26  honda  pilot awd            a
#
#    year
# 0  2018
# 1  2018
# 2  2018
# 3  2018

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2019&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2019 = json.loads(response.text)
pilot_df_2019 = pd.json_normalize(pilot_2019)
pilot_df_2019
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          6
# 1        19  small sport utility vehicle               22          6
# 2        19  small sport utility vehicle               22          6
# 3        18  small sport utility vehicle               21          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           27  honda  pilot fwd            a
# 1           3.5   fwd       gas           27  honda  pilot fwd            a
# 2           3.5   awd       gas           26  honda  pilot awd            a
# 3           3.5   awd       gas           26  honda  pilot awd            a
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019

# %%
model = "pilot"
api_url = 'https://api.api-ninjas.com/v1/cars?limit=50&year=2020&model=pilot'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': 'fKMDhJfN1z0WarUsLzvC+Q==amYiUlx5q7gwSHKA'})

# %%
pilot_2020 = json.loads(response.text)
pilot_df_2020 = pd.json_normalize(pilot_2020)
pilot_df_2020
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        20  small sport utility vehicle               23          6
# 1        19  small sport utility vehicle               22          6
# 2        19  small sport utility vehicle               22          6
# 3        18  small sport utility vehicle               21          6
#
#    displacement drive fuel_type  highway_mpg   make      model transmission  \
# 0           3.5   fwd       gas           27  honda  pilot fwd            a
# 1           3.5   fwd       gas           27  honda  pilot fwd            a
# 2           3.5   awd       gas           26  honda  pilot awd            a
# 3           3.5   awd       gas           26  honda  pilot awd            a
#
#    year
# 0  2020
# 1  2020
# 2  2020
# 3  2020

# %%
pilot_df_2010_2020 = pd.concat([pilot_df_2010, pilot_df_2011, pilot_df_2012, pilot_df_2013, pilot_df_2014, pilot_df_2015, pilot_df_2016, pilot_df_2017, pilot_df_2018, pilot_df_2019, pilot_df_2020])
pilot_df_2010_2020
# Out:
#    city_mpg                           class  combination_mpg  cylinders  \
# 0        17           sport utility vehicle               19          6
# 1        16           sport utility vehicle               18          6
# 0        17           sport utility vehicle               19          6
# 1        16           sport utility vehicle               18          6
# 0        18           sport utility vehicle               20          6
# 1        17           sport utility vehicle               20          6
# 0        18     small sport utility vehicle               20          6
# 1        17  standard sport utility vehicle               20          6
# 0        18     small sport utility vehicle               20          6
# 1        17     small sport utility vehicle               20          6
# 0        18     small sport utility vehicle               20          6
# 1        17     small sport utility vehicle               20          6
# ...

# %%
pilot_df_2010_2020.to_csv("pilot.csv")

# %%
prices = pd.read_csv("true_car_listings.csv")
prices['Make'] = prices['Make'].str.lower()
prices
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       acura    ILX6-Speed
# 1       acura    ILX5-Speed
# ...

# %%
prices_pilot = prices.loc[(prices["Make"] == "honda") & (prices["Model"] == "Pilot") | (prices["Model"] == "Pilot2WD") | (prices["Model"] == "Pilot4WD")]
prices_pilot
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 404484  12888  2011    23262  Long Island City    NY  5FNYF4H28BB075371
# 406133   7995  2007    67821           Kahului    HI  5FNYF28537B042848
# 406911  14995  2012    21107  Long Island City    NY  5FNYF4H71CB023691
# 410029  12800  2007    36061          Clermont    FL  5FNYF285X7B039669
# 410432   8981  2008    96058      Jacksonville    FL  5FNYF28228B018936
# ...       ...   ...      ...               ...   ...                ...
# 429098  41500  2016     8799         Fairfield    Oh  5FNYF6H95GB092922
# 429101  41860  2016    13332    Mechanicsville    VA  5FNYF6H06GB110071
# 429102  41995  2016    24799   Brooklyn Center    MN  5FNYF6H04GB043504
# 429112  41500  2016    38094           Houston    TX  5FNYF6H00GB043371
# 429114  39895  2016    32732    Mechanicsville    VA  5FNYF6H98GB025828
#
#          Make     Model
# 404484  honda  Pilot4WD
# 406133  honda  Pilot2WD
# 406911  honda  Pilot4WD
# ...

# %%
prices_pilot.to_csv("updated_pilot.csv")
